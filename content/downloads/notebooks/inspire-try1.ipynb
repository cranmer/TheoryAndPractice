# %% [markdown]
# # Convert inspire ID's into short python dictionaries for Website
# by Kyle Cranmer April 14, 2019

# %%
import requests
import json

# %%
#if you are running on Binder, you will need to uncomment the next line and execute it
#!pip install pyyaml

# %%
import yaml

# %%
recid_unpublished = 1726790 #notpublished
recid_published = 1705857 #published
recid = recid_unpublished
url = 'https://labs.inspirehep.net/api/literature/'+str(recid)

# %%
def summarize_record(recid):
    url = 'https://labs.inspirehep.net/api/literature/'+str(recid)
    max_authors = 5
    r = requests.get(url)
    data = r.json()['metadata']
    mini_dict = {'recid':recid}
    mini_dict.update({'title':data['titles'][0]['title']})
    if len(data['authors'])>max_authors:
        #mini_dict.update({'authors':[a['full_name'] for a in data['authors'][:max_authors]]+['et. al.']})
        mini_dict.update({'authors':"; ".join([a['full_name'] for a in data['authors'][:max_authors]]+['et. al.'])})
    else:
        mini_dict.update({'authors':[a['full_name'] for a in data['authors']]})

    if 'collaborations' in data:
        mini_dict.update({'collaboration': data['collaborations'][0]['value']})

    mini_dict.update({'arxiv_eprint': data['arxiv_eprints'][0]['value']})
    mini_dict.update({'url': 'https://arxiv.org/abs/'+data['arxiv_eprints'][0]['value']})
    mini_dict.update({'creation_date': data['legacy_creation_date']})

    if 'publication_info' in data:
        mini_dict.update({'journal_title':data['publication_info'][0]['journal_title']})
        mini_dict.update({'journal_volume':data['publication_info'][0]['journal_volume']})
        mini_dict.update({'page_start':data['publication_info'][0]['page_start']})
        mini_dict.update({'journal_year':data['publication_info'][0]['year']})
    
    if 'dois' in data:
        mini_dict.update({'doi': data['dois'][0]['value']})
    return mini_dict

# %%
def summarize_records(recids):
    return {'publications':[summarize_record(recid) for recid in recids]}

# %% [markdown]
# ## example summarizing 2 individual records

# %%
summarize_record(recid_published)
# Out:
# {'recid': 1705857,
#  'title': 'Measurements of fiducial and differential cross-sections of $t\\bar{t}$ production with additional heavy-flavour jets in proton-proton collisions at $\\sqrt{s}$ = 13 TeV with the ATLAS detector',
#  'authors': 'Aaboud, Morad; Aad, Georges; Abbott, Brad; Abdinov, Ovsat; Abeloos, Baptiste; et. al.',
#  'collaboration': 'ATLAS',
#  'arxiv_eprint': '1811.12113',
#  'url': 'https://arxiv.org/abs/1811.12113',
#  'creation_date': '2018-11-30',
#  'journal_title': 'JHEP',
#  'journal_volume': '04',
#  'page_start': '046',
#  'journal_year': 2019,
#  'doi': '10.1007/JHEP04(2019)046'}

# %%
summarize_record(recid_unpublished)
# Out:
# {'recid': 1726790,
#  'title': 'Machine learning and the physical sciences',
#  'authors': 'Carleo, Giuseppe; Cirac, Ignacio; Cranmer, Kyle; Daudet, Laurent; Schuld, Maria; et. al.',
#  'arxiv_eprint': '1903.10563',
#  'url': 'https://arxiv.org/abs/1903.10563',
#  'creation_date': '2019-03-27'}

# %% [markdown]
# ## example summarizing a list of records

# %%
list_of_recids = [recid_published, recid_unpublished]
print(yaml.dump(summarize_records(list_of_recids),default_flow_style=False))
# Out:
# publications:
# - arxiv_eprint: '1811.12113'
#   authors: Aaboud, Morad; Aad, Georges; Abbott, Brad; Abdinov, Ovsat; Abeloos, Baptiste;
#     et. al.
#   collaboration: ATLAS
#   creation_date: '2018-11-30'
#   doi: 10.1007/JHEP04(2019)046
#   journal_title: JHEP
#   journal_volume: '04'
#   journal_year: 2019
#   page_start: '046'
#   recid: 1705857
#   title: Measurements of fiducial and differential cross-sections of $t\bar{t}$ production
#     with additional heavy-flavour jets in proton-proton collisions at $\sqrt{s}$ =
#     13 TeV with the ATLAS detector
#   url: https://arxiv.org/abs/1811.12113
# - arxiv_eprint: '1903.10563'
#   authors: Carleo, Giuseppe; Cirac, Ignacio; Cranmer, Kyle; Daudet, Laurent; Schuld,
#     Maria; et. al.
#   creation_date: '2019-03-27'
#   recid: 1726790
#   title: Machine learning and the physical sciences
#   url: https://arxiv.org/abs/1903.10563

# %% [markdown]
# ## Playground

# %%
url
# Out:
# 'https://labs.inspirehep.net/api/literature/1726790'

# %%
r = requests.get(url)
r.json()
# Out:
# {'created': '2019-03-27T00:00:00+00:00',
#  'id': 1726790,
#  'links': {},
#  'metadata': {'$schema': 'https://labs.inspirehep.net/schemas/records/hep.json',
#   '_collections': ['Literature'],
#   '_desy_bookkeeping': [{'date': '2019-04-03',
#     'expert': 'L',
#     'status': 'full'},
#    {'date': '2019-04-07', 'expert': 'L', 'status': 'printed'}],
#   '_export_to': {'HAL': True},
#   'abstracts': [{'source': 'arXiv',
#     'value': 'Machine learning encompasses a broad range of algorithms and modeling tools used for a vast array of data processing tasks, which has entered most scientific disciplines in recent years. We review in a selective way the recent research on the interface between machine learning and physical sciences.This includes conceptual developments in machine learning (ML) motivated by physical insights, applications of machine learning techniques to several domains in physics, and cross-fertilization between the two fields. After giving basic notion of machine learning methods and principles, we describe examples of how statistical physics is used to understand methods in ML. We then move to describe applications of ML methods in particle physics and cosmology, quantum many body physics, quantum computing, and chemical and material physics. We also highlight research and development into novel computing architectures aimed at accelerating ML. In each of the sections we describe recent successes as well as domain-specific methodology and challenges.'}],
#   'acquisition_source': {'datetime': '2019-03-28T03:38:24.805848',
#    'method': 'hepcrawl',
#    'source': 'arXiv',
#    'submission_number': '1522732'},
#   'arxiv_eprints': [{'categories': ['physics.comp-ph',
#      'astro-ph.CO',
#      'cond-mat.dis-nn',
#      'hep-th',
#      'quant-ph'],
#     'value': '1903.10563'}],
#   'authors': [{'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/1601179'},
#       'value': 'Flatiron Inst., New York'}],
#     'emails': ['gcarleo@flatironinstitute.org'],
#     'full_name': 'Carleo, Giuseppe',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'G.Carleo.1'}],
#     'raw_affiliations': [{'value': 'Center for Computational Quantum Physics, Flatiron Institute, 162 5th Avenue, New York, NY 10010, USA'}],
#     'signature_block': 'CARLg',
#     'uuid': '3841a0e4-2772-4fed-80f8-7244fc21e8c9'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/905027'},
#       'value': 'Munich, Max Planck Inst. Quantenopt.'}],
#     'full_name': 'Cirac, Ignacio',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'I.I.Cirac.1'}],
#     'raw_affiliations': [{'value': 'Max-Planck-Institut fur Quantenoptik, Hans-Kopfermann-Straße 1, D-85748 Garching, Germany'}],
#     'signature_block': 'CARACi',
#     'uuid': '77ae7b60-4d93-4e20-8b04-e32867294ada'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/909498'},
#       'value': 'New York U., CCPP'}],
#     'full_name': 'Cranmer, Kyle',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'K.S.Cranmer.1'}],
#     'raw_affiliations': [{'value': 'Center for Cosmology and Particle Physics, Center of Data Science, New York University, 726 Broadway, New York, NY 10003, USA'}],
#     'record': {'$ref': 'http://labs.inspirehep.net/api/authors/1012846'},
#     'signature_block': 'CRANARk',
#     'uuid': 'b790672a-f390-41c8-b432-ac1ea72335bc'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/912221'},
#       'value': 'Unlisted, FR'}],
#     'full_name': 'Daudet, Laurent',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'L.Daudet.1'}],
#     'raw_affiliations': [{'value': 'LightOn, 2 rue de la Bourse, F-75002 Paris, France'}],
#     'signature_block': 'DADATl',
#     'uuid': '06070dc4-d2ef-4203-9172-7e4bf282a604'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/903577'},
#       'value': 'Natal U.'},
#      {'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/912258'},
#       'value': 'Unlisted, CA'}],
#     'full_name': 'Schuld, Maria',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Schuld.1'}],
#     'raw_affiliations': [{'value': 'University of KwaZulu-Natal, Durban 4000, South Africa'},
#      {'value': 'National Institute for Theoretical Physics, KwaZulu-Natal, Durban 4000, South Africa'},
#      {'value': 'Xanadu Quantum Computing, 777 Bay Street, M5B 2H7 Toronto, Canad'}],
#     'signature_block': 'SALDm',
#     'uuid': 'c395048b-a2d7-4955-ad41-52a9ec0154ce'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/902840'},
#       'value': 'Hebrew U.'}],
#     'full_name': 'Tishby, Naftali',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'N.Tishby.2'}],
#     'raw_affiliations': [{'value': 'The Hebrew University of Jerusalem, Edmond Safra Campus, Jerusalem 91904, Israel'}],
#     'signature_block': 'TASBYn',
#     'uuid': '3558a9b2-6bdf-4ab6-b186-e55eca5640aa'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/903067'},
#       'value': 'New York U.'}],
#     'full_name': 'Vogt-Maranto, Leslie',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'L.Vogt.Maranto.1'}],
#     'raw_affiliations': [{'value': 'Department of Chemistry, New York University, New York, NY 10003, USA'}],
#     'signature_block': 'MARANTl',
#     'uuid': 'fa4590c5-3477-46bd-b2f8-ee7ce5e9bcce'},
#    {'affiliations': [{'record': {'$ref': 'http://labs.inspirehep.net/api/institutions/1087875'},
#       'value': 'IPhT, Saclay'}],
#     'emails': ['lenka.zdeborova@cea.fr'],
#     'full_name': 'Zdeborová, Lenka',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'L.Zdeborova.1'}],
#     'raw_affiliations': [{'value': 'Institut de physique théorique, Université Paris Saclay, CNRS, CEA, F-91191 Gif-sur-Yvette, France†'}],
#     'signature_block': 'ZDABARAVl',
#     'uuid': 'e529863b-ff06-496c-b6cf-d47fac713296'}],
#   'citeable': True,
#   'control_number': 1726790,
#   'core': True,
#   'curated': True,
#   'document_type': ['article'],
#   'documents': [{'fulltext': True,
#     'key': '1903.10563.pdf',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727391/content.pdf%3B1'}],
#   'figures': [{'caption': 'Samples from the GALAXY-ZOO dataset versus generated samples using conditional generative adversarial network. Each synthetic image is a 128$\\times$128 colored image (here inverted) produced by conditioning on a set of features $y \\in [0,1]^{37}$ . The pair of observed and generated images in each column correspond to the same $y$ value. Reproduced from ~\\cite{2016arXiv160905796R}.',
#     'key': 'galaxy-gan.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727386/content.png%3B2'},
#    {'caption': 'Example of machine learning approach to the classification of experimental images from scanning tunneling microscopy of high-temperature superconductors. Images are classified according to the predictions of distinct types of periodic spatial modulations. Reproduced from \\cite{zhang_using_2018}',
#     'key': 'stm_class.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727385/content.png%3B2'},
#    {'caption': 'Clustering thousands of possible ice structures based on machine-learned descriptors identifies observed forms and groups similar structures together. Reproduced from ~\\cite{Engel:2018ki}.',
#     'key': 'IceStructureSearch.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727384/content.png%3B2'},
#    {'caption': 'Dark matter distribution in three cubes produced using different sets of parameters. Each cube is divided into small sub- cubes for training and prediction. Note that although cubes in this figure are produced using very different cosmological parameters in our constrained sampled set, the effect is not visually discernible.  Reproduced from ~\\cite{2017arXiv171102033R}.',
#     'key': 'dark-matter-distribution.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727387/content.png%3B2'},
#    {'caption': 'Several representations are currently used to describe molecular systems in ML models, including (a) atomic coordinates, with symmetry functions encoding local bonding environments, as inputs to element-based neural networks (Reproduced from ~\\cite{Gastegger:2017bi}) and (b) nuclear potentials approximated by a sum of Gaussian functions as inputs kernel ridge regression models for electron densities (Modified from ~\\cite{Brockherde:2017vd}).',
#     'key': 'MoleculeReps.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727390/content.png%3B2'},
#    {'caption': 'A schematic of machine learning based approaches to likelihood-free inference in which the simulation provides training data for a neural network that is subsequently used as a surrogate for the intractable likelihood during inference. Reproduced from ~\\cite{Brehmer:2018kdj}.',
#     'key': 'schematic-text.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727388/content.png%3B2'},
#    {'caption': '(Top) Example of a shallow convolutional neural network used to represent the many-body wave-function of a system of spin $1/2$ particles on a square lattice. (Bottom) Filters of a fully-connected convolutional RBM found in the variational learning of the ground-state of the two-dimensional Heisenberg model, adapted from \\cite{carleo_solving_2017}.',
#     'key': 'nqs_conv.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727392/content.png%3B2'},
#    {'caption': "Illustrations of the methods discussed in the text. 1. Optical components such as interferometers and amplifiers can emulate a neural network that layer-wise maps an input $x$ to $\\varphi(Wx)$ where $W$ is a learnable weight matrix and $\\varphi$ a nonlinear activation. Using quantum optics components such as displacement and squeezing, one can encode information into quantum properties of light and turn the neural net into a universal quantum computer. 2. Random embedding with an Optical Processing Unit. Data is encoded into the laser beam through a spatial light modulator (here, a DMD), after which a diffusive medium generates the random features. 3. A quantum computer can be used to compute distances between data points, or ``quantum kernels''. The first part of the quantum algorithm uses routines $S_x$, $S_{x'}$ to embed the data in Hilbert space, while the second part reveals the inner product of the embedded vectors. This kernel can be further processed in standard kernel methods such as support vector machines.",
#     'key': 'figure1.png',
#     'source': 'arxiv',
#     'url': 'file:///afs/cern.ch/project/inspire/PROD/var/data/files/g186/3727389/content.png%3B1'}],
#   'inspire_categories': [{'source': 'arxiv', 'term': 'Computing'},
#    {'source': 'arxiv', 'term': 'Astrophysics'},
#    {'source': 'arxiv', 'term': 'General Physics'},
#    {'source': 'arxiv', 'term': 'Theory-HEP'}],
#   'keywords': [{'schema': 'INSPIRE', 'value': '* Automatic Keywords *'},
#    {'schema': 'INSPIRE',
#     'source': 'bibclassify',
#     'value': 'computer: quantum'},
#    {'schema': 'INSPIRE',
#     'source': 'bibclassify',
#     'value': 'cosmological model'},
#    {'schema': 'INSPIRE',
#     'source': 'bibclassify',
#     'value': 'many-body problem'},
#    {'schema': 'INSPIRE', 'source': 'bibclassify', 'value': 'statistical'},
#    {'schema': 'INSPIRE', 'source': 'bibclassify', 'value': 'interface'}],
#   'legacy_creation_date': '2019-03-27',
#   'legacy_version': '20190411140323.0',
#   'license': [{'license': 'arXiv nonexclusive-distrib 1.0',
#     'material': 'preprint',
#     'url': 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/'}],
#   'number_of_pages': 44,
#   'preprint_date': '2019-03-25',
#   'references': [{'reference': {'authors': [{'full_name': 'Aaronson, S.'}],
#      'misc': ['(2007), Proceedings of the Royal Society A : Mathematical, Physical and Engineering Sciences 463 , 3089']}},
#    {'reference': {'arxiv_eprint': '1711.01053',
#      'authors': [{'full_name': 'Aaronson, S.'}],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Acar, E.'},
#       {'full_name': 'Yener, B.'}],
#      'publication_info': {'artid': '6',
#       'journal_title': 'IEEE Trans.Knowledge Data Eng.',
#       'journal_volume': '21',
#       'page_start': '6',
#       'year': 2009}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1498561'},
#     'reference': {'arxiv_eprint': '1611.05531',
#      'authors': [{'full_name': 'Acciarri, R.'}],
#      'misc': ['(MicroBooNE)'],
#      'publication_info': {'artid': 'P03011',
#       'journal_title': 'JINST',
#       'journal_volume': '12',
#       'year': 2017}}},
#    {'reference': {'arxiv_eprint': '1510.06356',
#      'authors': [{'full_name': 'Adachi, S.H.'},
#       {'full_name': 'Henderson, M.P.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2015}}},
#    {'reference': {'arxiv_eprint': '1710.03667',
#      'authors': [{'full_name': 'Advani, M.S.'}, {'full_name': 'Saxe, A.M.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Agresti, I.'},
#       {'full_name': 'Viggianiello, N.'},
#       {'full_name': 'Flamini, F.'},
#       {'full_name': 'Spagnolo, N.'},
#       {'full_name': 'Crespi, A.'},
#       {'full_name': 'Osellame, R.'},
#       {'full_name': 'Wiebe, N.'},
#       {'full_name': 'Sciarrino, F.'}],
#      'publication_info': {'artid': '011013',
#       'journal_title': 'Phys.Rev.X',
#       'journal_volume': '9',
#       'year': 2019}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1681439'},
#     'reference': {'arxiv_eprint': '1807.02876',
#      'authors': [{'full_name': 'Albertsson, K.'}],
#      'misc': ['(2018), Proceedings, 18th International Workshop on Advanced Computing and Analysis Techniques in Physics Research (ACAT): Seattle, WA, USA, August 21-25'],
#      'publication_info': {'artid': '022008',
#       'journal_title': 'J.Phys.Conf.Ser.',
#       'journal_volume': '1085',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Alet, F.'},
#       {'full_name': 'Laflorencie, N.'}],
#      'misc': ['Comptes Rendus Physique Quantum simulation / Simulation quantique, 19 (6), 498'],
#      'publication_info': {'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1723733'},
#     'reference': {'arxiv_eprint': '1903.01473',
#      'authors': [{'full_name': 'Alsing, J.'}, {'full_name': 'Wandelt, B.'}],
#      'publication_info': {'year': 2019}}},
#    {'reference': {'authors': [{'full_name': 'Alsing, J.'},
#       {'full_name': 'Wandelt, B.'},
#       {'full_name': 'Feeney, S.'}],
#      'misc': ['Mon. Not. Roy'],
#      'publication_info': {'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1646202'},
#     'reference': {'arxiv_eprint': '1801.01497',
#      'misc': ['Astron. Soc. 477 (3), 2874']}},
#    {'reference': {'authors': [{'full_name': 'Amari, S.'}],
#      'misc': ['-i'],
#      'publication_info': {'artid': '251',
#       'journal_title': 'Neural Comput.',
#       'journal_volume': '10',
#       'page_start': '251',
#       'year': 1998}}},
#    {'reference': {'authors': [{'full_name': 'Ambrogio, S.'},
#       {'full_name': 'Narayanan, P.'},
#       {'full_name': 'Tsai, H.'},
#       {'full_name': 'Shelby, R.M.'},
#       {'full_name': 'Boybat, I.'},
#       {'full_name': 'Nolfo, C.'},
#       {'full_name': 'Sidler, S.'},
#       {'full_name': 'Giordano, M.'},
#       {'full_name': 'Bodini, M.'},
#       {'full_name': 'Farinha, N.C.'}],
#      'misc': ['Nature 558 (7708), 60'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Ambs, P.'}],
#      'misc': ['Advances in Optical Technologies'],
#      'publication_info': {'year': 2010}}},
#    {'reference': {'authors': [{'full_name': 'Amit, D.J.'},
#       {'full_name': 'Gutfreund, H.'},
#       {'full_name': 'Sompolinsky, H.'}],
#      'publication_info': {'artid': '1007',
#       'journal_title': 'Phys.Rev.A',
#       'journal_volume': '32',
#       'page_start': '1007',
#       'year': 1985}}},
#    {'reference': {'authors': [{'full_name': 'Anandkumar, A.'},
#       {'full_name': 'Ge, R.'},
#       {'full_name': 'Hsu, D.'},
#       {'full_name': 'Kakade, S.M.'},
#       {'full_name': 'Telgarsky, M.'}],
#      'publication_info': {'artid': '2773',
#       'journal_title': 'J.Machine Learning Res.',
#       'journal_volume': '15',
#       'page_start': '2773',
#       'year': 2014}}},
#    {'reference': {'authors': [{'full_name': 'Anelli, A.'},
#       {'full_name': 'Engel, E.A.'},
#       {'full_name': 'Pickard, C.J.'},
#       {'full_name': 'Ceriotti, M.'}],
#      'misc': ['Phys. Rev'],
#      'publication_info': {'artid': '103804',
#       'journal_title': 'Materials',
#       'journal_volume': '2',
#       'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1601167'},
#     'reference': {'arxiv_eprint': '1705.08830',
#      'authors': [{'full_name': 'Apollinari, G.'},
#       {'full_name': 'Brüning, O.'},
#       {'full_name': 'Nakamoto, T.'},
#       {'full_name': 'Rossi, L.'}],
#      'misc': ['CERN Yellow Report (5), 1'],
#      'publication_info': {'year': 2015}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1699400'},
#     'reference': {'arxiv_eprint': '1810.08430',
#      'authors': [{'full_name': 'Armitage, T.J.'},
#       {'full_name': 'Kay, S.T.'},
#       {'full_name': 'Barnes, D.J.'}],
#      'publication_info': {'artid': '1526',
#       'journal_title': 'Mon.Not.Roy.Astron.Soc.',
#       'journal_volume': '484',
#       'page_start': '1526',
#       'year': 2019}}},
#    {'reference': {'authors': [{'full_name': 'Arsenault, L.-F.'},
#       {'full_name': 'Neuberg, R.'},
#       {'full_name': 'Hannah, L.A.'},
#       {'full_name': 'Millis, A.J.'}],
#      'publication_info': {'artid': '115007',
#       'journal_title': 'Inverse Prob.',
#       'journal_volume': '33',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Arunachalam, S.'},
#       {'full_name': 'de Wolf, R.'}],
#      'misc': ['ACM'],
#      'publication_info': {'artid': '41',
#       'journal_title': 'Sigact News',
#       'journal_volume': '48',
#       'page_start': '41',
#       'year': 2017}}},
#    {'reference': {'collaborations': ['ATLAS Collaboration'],
#      'misc': ['Deep generative models for fast shower simulation in ATLAS, Tech. Rep. ATL-SOFTPUB--001 (CERN, Geneva)'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1806.05451',
#      'authors': [{'full_name': 'Aubin, B.'},
#       {'full_name': 'Maillard, A.'},
#       {'full_name': 'Barbier, J.'},
#       {'full_name': 'Krzakala, F.'},
#       {'full_name': 'Macris, N.'},
#       {'full_name': 'Zdeborov, L.'}],
#      'misc': ['in NeurIPS, arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1444342'},
#     'reference': {'arxiv_eprint': '1604.01444',
#      'authors': [{'full_name': 'Aurisano, A.'},
#       {'full_name': 'Radovic, A.'},
#       {'full_name': 'Rocco, D.'},
#       {'full_name': 'Himmel, A.'},
#       {'full_name': 'Messier, M.D.'},
#       {'full_name': 'Niner, E.'},
#       {'full_name': 'Pawloski, G.'},
#       {'full_name': 'Psihas, F.'},
#       {'full_name': 'Sousa, A.'},
#       {'full_name': 'Vahle, P.'}],
#      'publication_info': {'artid': 'P09001',
#       'journal_title': 'JINST',
#       'journal_volume': '11',
#       'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Baireuther, P.'},
#       {'full_name': "O'Brien, T.E."},
#       {'full_name': 'Tarasinski, B.'}],
#      'misc': ['and C. W. J']}},
#    {'reference': {'misc': ['Beenakker , Quantum 2, 48'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1803.06969',
#      'authors': [{'full_name': 'Baity-Jesi, M.'},
#       {'full_name': 'Sagun, L.'},
#       {'full_name': 'Geiger, M.'},
#       {'full_name': 'Spigler, S.'},
#       {'full_name': 'Arous, G.B.'},
#       {'full_name': 'Cammarota, C.'},
#       {'full_name': 'LeCun, Y.'},
#       {'full_name': 'Wyart, M.'},
#       {'full_name': 'Biroli, G.'}],
#      'misc': ['in ICML, arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Baldassi, C.'},
#       {'full_name': 'Borgs, C.'},
#       {'full_name': 'Chayes, J.T.'},
#       {'full_name': 'Ingrosso, A.'},
#       {'full_name': 'Lucibello, C.'},
#       {'full_name': 'Saglietti, L.'},
#       {'full_name': 'Zecchina, R.'}],
#      'publication_info': {'artid': 'E7655',
#       'journal_title': 'Proc.Nat.Acad.Sci.',
#       'journal_volume': '113',
#       'page_start': 'E7655',
#       'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Baldassi, C.'},
#       {'full_name': 'Ingrosso, A.'},
#       {'full_name': 'Lucibello, C.'},
#       {'full_name': 'Saglietti, L.'},
#       {'full_name': 'Zecchina, R.'}],
#      'publication_info': {'artid': '128101',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '115',
#       'year': 2015}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1437937'},
#     'reference': {'authors': [{'full_name': 'Baldi, P.'},
#       {'full_name': 'Bauer, K.'},
#       {'full_name': 'Eng, C.'},
#       {'full_name': 'Sadowski, P.'},
#       {'full_name': 'Whiteson, D.'}],
#      'misc': ['(a)'],
#      'publication_info': {'artid': '094034',
#       'journal_title': 'Phys.Rev.D',
#       'journal_volume': '93',
#       'year': 2016}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1418479'},
#     'reference': {'arxiv_eprint': '1601.07913',
#      'authors': [{'full_name': 'Baldi, P.'},
#       {'full_name': 'Cranmer, K.'},
#       {'full_name': 'Faucett, T.'},
#       {'full_name': 'Sadowski, P.'},
#       {'full_name': 'Whiteson, D.'}],
#      'misc': ['(b)'],
#      'publication_info': {'artid': '235',
#       'journal_title': 'Eur.Phys.J.C',
#       'journal_volume': '76',
#       'page_start': '235',
#       'year': 2016}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1281836'},
#     'reference': {'arxiv_eprint': '1402.4735',
#      'authors': [{'full_name': 'Baldi, P.'},
#       {'full_name': 'Sadowski, P.'},
#       {'full_name': 'Whiteson, D.'}],
#      'publication_info': {'artid': '4308',
#       'journal_title': 'Nature Commun.',
#       'journal_volume': '5',
#       'page_start': '4308',
#       'year': 2014}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1325552'},
#     'reference': {'arxiv_eprint': '1410.8849',
#      'authors': [{'full_name': 'Ball, R.D.'}],
#      'misc': ['(NNPDF)'],
#      'publication_info': {'artid': '040',
#       'journal_title': 'JHEP',
#       'journal_volume': '04',
#       'page_start': '040',
#       'year': 2015}}},
#    {'reference': {'authors': [{'full_name': 'Ballard, A.J.'},
#       {'full_name': 'Das, R.'},
#       {'full_name': 'Martiniani, S.'},
#       {'full_name': 'Mehta, D.'},
#       {'full_name': 'Sagun, L.'},
#       {'full_name': 'Stevenson, J.D.'},
#       {'full_name': 'Wales, D.J.'}],
#      'publication_info': {'artid': '12585',
#       'journal_title': 'Phys.Chem.Chem.Phys.',
#       'journal_volume': '19',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Banchi, L.'},
#       {'full_name': 'Grant, E.'},
#       {'full_name': 'Rocchetto, A.'},
#       {'full_name': 'Severini, S.'}],
#      'publication_info': {'artid': '123030',
#       'journal_title': 'New J.Phys.',
#       'journal_volume': '20',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Bang, J.'},
#       {'full_name': 'Ryu, J.'},
#       {'full_name': 'Yoo, S.'},
#       {'full_name': 'Pawłowski, M.'},
#       {'full_name': 'Lee, J.'}],
#      'publication_info': {'artid': '073017',
#       'journal_title': 'New J.Phys.',
#       'journal_volume': '16',
#       'year': 2014}}},
#    {'reference': {'authors': [{'full_name': 'Barbier, J.'},
#       {'full_name': 'Dia, M.'},
#       {'full_name': 'Macris, N.'},
#       {'full_name': 'Krzakala, F.'},
#       {'full_name': 'Lesieur, T.'},
#       {'full_name': 'Zdeborov, L.'}],
#      'misc': ['in Advances in Neural Information Processing Systems, pp. 424-432'],
#      'publication_info': {'year': 2016}}},
#    {'reference': {'arxiv_eprint': '1708.03395',
#      'authors': [{'full_name': 'Barbier, J.'},
#       {'full_name': 'Krzakala, F.'},
#       {'full_name': 'Macris, N.'},
#       {'full_name': 'Miolane, L.'},
#       {'full_name': 'Zdeborov, L.'}],
#      'misc': ['to appear in PNAS, arXiv preprint'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Barkai, N.'},
#       {'full_name': 'Sompolinsky, H.'}],
#      'publication_info': {'artid': '1766',
#       'journal_title': 'Phys.Rev.E',
#       'journal_volume': '50',
#       'page_start': '1766',
#       'year': 1994}}},
#    {'reference': {'authors': [{'full_name': 'Barra, A.'},
#       {'full_name': 'Genovese, G.'},
#       {'full_name': 'Sollich, P.'},
#       {'full_name': 'Tantari, D.'}],
#      'publication_info': {'artid': '022310',
#       'journal_title': 'Phys.Rev.E',
#       'journal_volume': '97',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Bartók, A.P.'},
#       {'full_name': 'Kermode, J.'},
#       {'full_name': 'Bernstein, N.'},
#       {'full_name': 'Csányi, G.'}],
#      'publication_info': {'artid': '041048',
#       'journal_title': 'Phys.Rev.X',
#       'journal_volume': '8',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Bartók, A.P.'},
#       {'full_name': 'Kondor, R.'},
#       {'full_name': 'Csányi, G.'}],
#      'publication_info': {'artid': '184115',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '87',
#       'year': 2013}}},
#    {'reference': {'authors': [{'full_name': 'Bartók, A.P.'},
#       {'full_name': 'Payne, M.C.'},
#       {'full_name': 'Kondor, R.'},
#       {'full_name': 'Csányi, G.'}],
#      'publication_info': {'artid': '136403',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '104',
#       'year': 2010}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1683311'},
#     'reference': {'arxiv_eprint': '1807.07706',
#      'authors': [{'full_name': 'Baydin, A.G.'},
#       {'full_name': 'Heinrich, L.'},
#       {'full_name': 'Bhimji, W.'},
#       {'full_name': 'Gram-Hansen, B.'},
#       {'full_name': 'Louppe, G.'},
#       {'full_name': 'Shao, L.'},
#       {'full_name': 'Prabhat, K.'}],
#      'misc': ['Cranmer, and F. Wood'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Beach, M.J.S.'},
#       {'full_name': 'Golubeva, A.'},
#       {'full_name': 'Melko, R.G.'}],
#      'publication_info': {'artid': '045207',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '97',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Beaumont, M.A.'},
#       {'full_name': 'Zhang, W.'},
#       {'full_name': 'Balding, D.J.'}],
#      'misc': ['Genetics 162 (4), 2025'],
#      'publication_info': {'year': 2002}}},
#    {'reference': {'authors': [{'full_name': 'Becca, F.'},
#       {'full_name': 'Sorella, S.'}],
#      'misc': ['Quantum Monte Carlo Approaches for Correlated Systems (Cambridge University Press, Cambridge, United Kingdom'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'misc': ['New York, NY)']}},
#    {'reference': {'authors': [{'full_name': 'Behler, J.'}],
#      'publication_info': {'artid': '170901',
#       'journal_title': 'J.Chem.Phys.',
#       'journal_volume': '145',
#       'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Behler, J.'},
#       {'full_name': 'Parrinello, M.'}],
#      'publication_info': {'artid': '583',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '98',
#       'page_start': '583',
#       'year': 2007}}},
#    {'reference': {'authors': [{'full_name': 'Benedetti, M.'},
#       {'full_name': 'Realpe-Gómez, J.'},
#       {'full_name': 'Biswas, R.'},
#       {'full_name': 'Perdomo-Ortiz, A.'}],
#      'publication_info': {'artid': '041052',
#       'journal_title': 'Phys.Rev.X',
#       'journal_volume': '7',
#       'year': 2017}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/491012'},
#     'reference': {'authors': [{'full_name': 'Benítez, N.'}],
#      'misc': ['arXiv:astroph/9811189 [astro-ph]'],
#      'publication_info': {'artid': '571',
#       'journal_title': 'Astrophys.J.',
#       'journal_volume': '536',
#       'page_start': '571',
#       'year': 2000}}},
#    {'reference': {'arxiv_eprint': '1301.3124',
#      'authors': [{'full_name': 'Bény, C.'}],
#      'misc': ['in ICLR, arXiv preprint'],
#      'publication_info': {'year': 2013}}},
#    {'reference': {'authors': [{'full_name': 'Bereau, T.'},
#       {'full_name': 'DiStasio, R.A.'}],
#      'misc': ['Jr., A. Tkatchenko, and O. A. von Lilienfeld'],
#      'publication_info': {'artid': '241706',
#       'journal_title': 'J.Chem.Phys.',
#       'journal_volume': '148',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Biamonte, J.'},
#       {'full_name': 'Wittek, P.'},
#       {'full_name': 'Pancotti, N.'},
#       {'full_name': 'Rebentrost, P.'},
#       {'full_name': 'Wiebe, N.'},
#       {'full_name': 'Lloyd, S.'}],
#      'misc': ['Nature 549 (7671), 195'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Biehl, M.'},
#       {'full_name': 'Mietzner, A.'}],
#      'misc': ['EPL'],
#      'publication_info': {'artid': '421',
#       'journal_title': 'Europhys.Lett.',
#       'journal_volume': '24',
#       'page_start': '421',
#       'year': 1993}}},
#    {'reference': {'authors': [{'full_name': 'Bishop, C.M.'}],
#      'imprint': {'publisher': 'Springer'},
#      'misc': ['Pattern recognition and machine learning'],
#      'publication_info': {'year': 2006}}},
#    {'reference': {'arxiv_eprint': '1811.12425',
#      'authors': [{'full_name': 'Bohrdt, A.'},
#       {'full_name': 'Chiu, C.S.'},
#       {'full_name': 'Ji, G.'},
#       {'full_name': 'Xu, M.'},
#       {'full_name': 'Greif, D.'},
#       {'full_name': 'Greiner, M.'},
#       {'full_name': 'Demler, E.'},
#       {'full_name': 'Grusdt, F.'},
#       {'full_name': 'Knap, M.'}],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Bolthausen, E.'}],
#      'publication_info': {'artid': '333',
#       'journal_title': 'Commun.Math.Phys.',
#       'journal_volume': '325',
#       'page_start': '333',
#       'year': 2014}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1384099'},
#     'reference': {'arxiv_eprint': '1507.05909',
#      'authors': [{'full_name': 'Bonnett, C.'}],
#      'misc': ['(DES)'],
#      'publication_info': {'artid': '042005',
#       'journal_title': 'Phys.Rev.D',
#       'journal_volume': '94',
#       'year': 2016}}},
#    {'reference': {'arxiv_eprint': '1901.08615',
#      'authors': [{'full_name': 'Borin, A.'}, {'full_name': 'Abanin, D.A.'}],
#      'misc': ['[condmat, physics:quant-ph]'],
#      'publication_info': {'year': 2019}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1702304'},
#     'reference': {'arxiv_eprint': '1811.01242',
#      'authors': [{'full_name': 'Bozson, A.'},
#       {'full_name': 'Cowan, G.'},
#       {'full_name': 'Span, F.'}],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Bradde, S.'},
#       {'full_name': 'Bialek, W.'}],
#      'publication_info': {'artid': '462',
#       'journal_title': 'J.Statist.Phys.',
#       'journal_volume': '167',
#       'page_start': '462',
#       'year': 2017}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/790440'},
#     'reference': {'arxiv_eprint': '0807.1533',
#      'authors': [{'full_name': 'Brammer, G.B.'},
#       {'full_name': 'van Dokkum, P.G.'},
#       {'full_name': 'Coppi, P.'}],
#      'publication_info': {'artid': '1503',
#       'journal_title': 'Astrophys.J.',
#       'journal_volume': '686',
#       'page_start': '1503',
#       'year': 2008}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1670939'},
#     'reference': {'arxiv_eprint': '1805.00020',
#      'authors': [{'full_name': 'Brehmer, J.'},
#       {'full_name': 'Cranmer, K.'},
#       {'full_name': 'Louppe, G.'},
#       {'full_name': 'Pavez, J.'}],
#      'misc': ['(a)'],
#      'publication_info': {'artid': '052004',
#       'journal_title': 'Phys.Rev.D',
#       'journal_volume': '98',
#       'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1670936'},
#     'reference': {'arxiv_eprint': '1805.00013',
#      'authors': [{'full_name': 'Brehmer, J.'},
#       {'full_name': 'Cranmer, K.'},
#       {'full_name': 'Louppe, G.'},
#       {'full_name': 'Pavez, J.'}],
#      'misc': ['(b)'],
#      'publication_info': {'artid': '111801',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '121',
#       'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1675782'},
#     'reference': {'arxiv_eprint': '1805.12244',
#      'authors': [{'full_name': 'Brehmer, J.'},
#       {'full_name': 'Louppe, G.'},
#       {'full_name': 'Pavez, J.'},
#       {'full_name': 'Cranmer, K.'}],
#      'misc': ['(c)'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Breiman, L.'},
#       {'full_name': 'Friedman, J.H.'},
#       {'full_name': 'Olshen, R.A.'},
#       {'full_name': 'Stone, C.J.'}],
#      'publication_info': {'year': 1984}}},
#    {'reference': {'authors': [{'full_name': 'Brockherde, F.'},
#       {'full_name': 'Vogt, L.'},
#       {'full_name': 'Li, L.'},
#       {'full_name': 'Tuckerman, M.E.'},
#       {'full_name': 'Burke, K.'},
#       {'full_name': 'Müller, K.-R.'}],
#      'misc': ['Nat. Commun. 8 (1), 872'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'arxiv_eprint': '1707.00663',
#      'authors': [{'full_name': 'Broecker, P.'},
#       {'full_name': 'Assaad, F.F.'},
#       {'full_name': 'Trebst, S.'}],
#      'misc': ['(a)'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Broecker, P.'},
#       {'full_name': 'Carrasquilla, J.'},
#       {'full_name': 'Melko, R.G.'},
#       {'full_name': 'Trebst, S.'}],
#      'misc': ['(b)'],
#      'publication_info': {'artid': '8823',
#       'journal_title': 'Sci.Rep.',
#       'journal_volume': '7',
#       'page_start': '8823',
#       'year': 2017}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1646174'},
#     'reference': {'arxiv_eprint': '1611.08097',
#      'authors': [{'full_name': 'Bronstein, M.M.'},
#       {'full_name': 'Bruna, J.'},
#       {'full_name': 'LeCun, Y.'},
#       {'full_name': 'Szlam, A.'},
#       {'full_name': 'Vandergheynst, P.'}],
#      'publication_info': {'artid': '18',
#       'journal_title': 'IEEE Sig.Proc.Mag.',
#       'journal_volume': '34',
#       'page_start': '18',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Bukov, M.'}],
#      'publication_info': {'artid': '224305',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '98',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Bukov, M.'},
#       {'full_name': 'Day, A.G.'},
#       {'full_name': 'Sels, D.'},
#       {'full_name': 'Weinberg, P.'},
#       {'full_name': 'Polkovnikov, A.'},
#       {'full_name': 'Mehta, P.'}],
#      'publication_info': {'artid': '031086',
#       'journal_title': 'Phys.Rev.X',
#       'journal_volume': '8',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Butler, K.T.'},
#       {'full_name': 'Davies, D.W.'},
#       {'full_name': 'Cartwright, H.'},
#       {'full_name': 'Isayev, O.'},
#       {'full_name': 'Walsh, A.'}],
#      'publication_info': {'artid': '547',
#       'journal_title': 'Nature',
#       'journal_volume': '559',
#       'page_start': '547',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Cai, Z.'},
#       {'full_name': 'Liu, J.'}],
#      'publication_info': {'artid': '035116',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '97',
#       'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1088313'},
#     'reference': {'arxiv_eprint': '1202.1426',
#      'authors': [{'full_name': 'Cameron, E.'}, {'full_name': 'Pettitt, A.N.'}],
#      'publication_info': {'artid': '44',
#       'journal_title': 'Mon.Not.Roy.Astron.Soc.',
#       'journal_volume': '425',
#       'page_start': '44',
#       'year': 2012}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1608405'},
#     'reference': {'arxiv_eprint': '1707.00655',
#      'authors': [{'full_name': 'Carifio, J.'},
#       {'full_name': 'Halverson, J.'},
#       {'full_name': 'Krioukov, D.'},
#       {'full_name': 'Nelson, B.D.'}],
#      'publication_info': {'artid': '157',
#       'journal_title': 'JHEP',
#       'journal_volume': '09',
#       'page_start': '157',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Carleo, G.'},
#       {'full_name': 'Becca, F.'},
#       {'full_name': 'Schiro, M.'},
#       {'full_name': 'Fabrizio, M.'}],
#      'publication_info': {'artid': '243',
#       'journal_title': 'Sci.Rep.',
#       'journal_volume': '2',
#       'page_start': '243',
#       'year': 2012}}},
#    {'reference': {'authors': [{'full_name': 'Carleo, G.'},
#       {'full_name': 'Nomura, Y.'},
#       {'full_name': 'Imada, M.'}],
#      'publication_info': {'artid': '5322',
#       'journal_title': 'Nature Commun.',
#       'journal_volume': '9',
#       'page_start': '5322',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Carleo, G.'},
#       {'full_name': 'Troyer, M.'}],
#      'misc': ['Science 355 (6325), 602'],
#      'publication_info': {'year': 2017}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1225852'},
#     'reference': {'arxiv_eprint': '1303.7269',
#      'authors': [{'full_name': 'Kind, M.'}, {'full_name': 'Brunner, R.J.'}],
#      'misc': ['Carrasco'],
#      'publication_info': {'artid': '1483',
#       'journal_title': 'Mon.Not.Roy.Astron.Soc.',
#       'journal_volume': '432',
#       'page_start': '1483',
#       'year': 2013}}},
#    {'reference': {'authors': [{'full_name': 'Carrasquilla, J.'},
#       {'full_name': 'Melko, R.G.'}],
#      'publication_info': {'artid': '431',
#       'journal_title': 'Nature Phys.',
#       'journal_volume': '13',
#       'page_start': '431',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Carrasquilla, J.'},
#       {'full_name': 'Torlai, G.'},
#       {'full_name': 'Melko, R.G.'},
#       {'full_name': 'Aolita, L.'}],
#      'misc': ['Nature Machine Intelligence 1 (3), 155'],
#      'publication_info': {'year': 2019}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1658833'},
#     'reference': {'arxiv_eprint': '1712.07901',
#      'authors': [{'full_name': 'Casado, M.L.'}],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Changlani, H.J.'},
#       {'full_name': 'Kinder, J.M.'},
#       {'full_name': 'Umrigar, C.J.'}],
#      'misc': ['and G. K.-L']}},
#    {'reference': {'misc': ['Chan'],
#      'publication_info': {'artid': '245116',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '80',
#       'year': 2009}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1654693'},
#     'reference': {'arxiv_eprint': '1802.03537',
#      'authors': [{'full_name': 'Charnock, T.'},
#       {'full_name': 'Lavaux, G.'},
#       {'full_name': 'Wandelt, B.D.'}],
#      'publication_info': {'artid': '083004',
#       'journal_title': 'Phys.Rev.D',
#       'journal_volume': '97',
#       'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1611.01838',
#      'authors': [{'full_name': 'Chaudhari, P.'},
#       {'full_name': 'Choromanska, A.'},
#       {'full_name': 'Soatto, S.'},
#       {'full_name': 'LeCun, Y.'},
#       {'full_name': 'Baldassi, C.'},
#       {'full_name': 'Borgs, C.'},
#       {'full_name': 'Chayes, J.'},
#       {'full_name': 'Sagun, L.'},
#       {'full_name': 'Zecchina, R.'}],
#      'misc': ['in ICLR 2017, arXiv preprint'],
#      'publication_info': {'year': 2016}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1682242'},
#     'reference': {'authors': [{'full_name': 'Chen, C.'},
#       {'full_name': 'Xu, X.Y.'},
#       {'full_name': 'Liu, J.'},
#       {'full_name': 'Batrouni, G.'},
#       {'full_name': 'Scalettar, R.'},
#       {'full_name': 'Meng, Z.Y.'}],
#      'misc': ['(a)'],
#      'publication_info': {'artid': '041102',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '98',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Chen, J.'},
#       {'full_name': 'Cheng, S.'},
#       {'full_name': 'Xie, H.'},
#       {'full_name': 'Wang, L.'},
#       {'full_name': 'Xiang, T.'}],
#      'misc': ['(b)'],
#      'publication_info': {'artid': '085104',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '97',
#       'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1901.02217',
#      'authors': [{'full_name': 'Cheng, S.'},
#       {'full_name': 'Wang, L.'},
#       {'full_name': 'Xiang, T.'},
#       {'full_name': 'Zhang, P.'}],
#      'misc': ['[cond-mat, physics:quant-ph, stat]'],
#      'publication_info': {'year': 2019}}},
#    {'reference': {'authors': [{'full_name': 'Chmiela, S.'},
#       {'full_name': 'Sauceda, H.E.'},
#       {'full_name': 'Müller, K.-R.'},
#       {'full_name': 'Tkatchenko, A.'}],
#      'misc': ['Nat. Commun. 9, 3887'],
#      'publication_info': {'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1694313'},
#     'reference': {'arxiv_eprint': '1809.06166',
#      'authors': [{'full_name': 'Choma, N.'},
#       {'full_name': 'Monti, F.'},
#       {'full_name': 'Gerhardt, L.'},
#       {'full_name': 'Palczewski, T.'},
#       {'full_name': 'Ronaghi, Z.'},
#       {'full_name': 'Prabhat'},
#       {'full_name': 'Bhimji, W.'},
#       {'full_name': 'M. M. Bronstein, S.R.'}],
#      'misc': ['Klein, and J. Bruna , arXiv e-prints'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Choo, K.'},
#       {'full_name': 'Carleo, G.'},
#       {'full_name': 'Regnault, N.'},
#       {'full_name': 'Neupert, T.'}],
#      'publication_info': {'artid': '167204',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '121',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Choromanska, A.'},
#       {'full_name': 'Henaff, M.'},
#       {'full_name': 'Mathieu, M.'},
#       {'full_name': 'Arous, G.B.'},
#       {'full_name': 'LeCun, Y.'}],
#      'misc': ['in Artificial Intelligence and Statistics, pp. 192-204'],
#      'publication_info': {'year': 2015}}},
#    {'reference': {'authors': [{'full_name': 'Chung, S.'},
#       {'full_name': 'Lee, D.D.'},
#       {'full_name': 'Sompolinsky, H.'}],
#      'publication_info': {'artid': '031003',
#       'journal_title': 'Phys.Rev.X',
#       'journal_volume': '8',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Ciliberto, C.'},
#       {'full_name': 'Herbster, M.'},
#       {'full_name': 'Ialongo, A.D.'},
#       {'full_name': 'Pontil, M.'},
#       {'full_name': 'Rocchetto, A.'},
#       {'full_name': 'Severini, S.'},
#       {'full_name': 'Wossnig, L.'}],
#      'misc': ['Proceedings of the Royal Society A : Mathematical, Physical and Engineering Sciences 474 (2209), 20170551'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Clark, S.R.'}],
#      'misc': ['Journal of Physics A: Mathematical and Theoretical 51 (13), 135301'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Clements, W.R.'},
#       {'full_name': 'Humphreys, P.C.'},
#       {'full_name': 'Metcalf, B.J.'},
#       {'full_name': 'Kolthammer, W.S.'},
#       {'full_name': 'Walmsley, I.A.'}],
#      'misc': ['Optica 3 (12), 1460'],
#      'publication_info': {'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Cocco, S.'},
#       {'full_name': 'Monasson, R.'},
#       {'full_name': 'Posani, L.'},
#       {'full_name': 'Rosay, S.'},
#       {'full_name': 'Tubiana, J.'}],
#      'misc': ['Physica A: Statistical Mechanics and its Applications 504, 45'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Cohen, N.'},
#       {'full_name': 'Sharir, O.'},
#       {'full_name': 'Shashua, A.'}],
#      'misc': ['in 29th Annual Conference on Learning Theory, Proceedings of Machine Learning Research, Vol. 49, V. Feldman, A. Rakhlin, and O. Shamir (eds.) (PMLR, Columbia University, New York, New York, USA) pp. 698-728'],
#      'publication_info': {'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Cohen, T.'},
#       {'full_name': 'Welling, M.'}],
#      'misc': ['in International conference on machine learning, pp. 2990-2999'],
#      'publication_info': {'year': 2016}}},
#    {'reference': {'arxiv_eprint': '1801.10130',
#      'authors': [{'full_name': 'Cohen, T.S.'},
#       {'full_name': 'Geiger, M.'},
#       {'full_name': 'Köhler, J.'},
#       {'full_name': 'Welling, M.'}],
#      'misc': ['Proceedings of the 6th International Conference on Learning Representations (ICLR) ArXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1902.04615',
#      'authors': [{'full_name': 'Cohen, T.S.'},
#       {'full_name': 'Weiler, M.'},
#       {'full_name': 'Kicanaoglu, B.'},
#       {'full_name': 'Welling, M.'}],
#      'misc': ['arXiv e-prints'],
#      'publication_info': {'year': 2019}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1672834'},
#     'reference': {'authors': [{'full_name': 'Coja-Oghlan, A.'},
#       {'full_name': 'Krzakala, F.'},
#       {'full_name': 'Perkins, W.'},
#       {'full_name': 'Zdeborov, L.'}],
#      'publication_info': {'artid': '694',
#       'journal_title': 'Adv.Math.',
#       'journal_volume': '333',
#       'page_start': '694',
#       'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1382125'},
#     'reference': {'authors': [{'full_name': 'Collett, T.E.'}],
#      'publication_info': {'artid': '20',
#       'journal_title': 'Astrophys.J.',
#       'journal_volume': '811',
#       'page_start': '20',
#       'year': 2015}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/632349'},
#     'reference': {'authors': [{'full_name': 'Collister, A.A.'},
#       {'full_name': 'Lahav, O.'}],
#      'misc': ['arXiv:astroph/0311058 [astro-ph]'],
#      'publication_info': {'artid': '345',
#       'journal_title': 'Publ.Astron.Soc.Pac.',
#       'journal_volume': '116',
#       'page_start': '345',
#       'year': 2004}}},
#    {'reference': {'arxiv_eprint': '1810.03787',
#      'authors': [{'full_name': 'Cong, I.'},
#       {'full_name': 'Choi, S.'},
#       {'full_name': 'Lukin, M.D.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1503115'},
#     'reference': {'authors': [{'full_name': 'Cranmer, K.'},
#       {'full_name': 'Louppe, G.'}],
#      'dois': ['10.5281/zenodo.198541'],
#      'misc': ['J. Brief Ideas'],
#      'publication_info': {'year': 2016}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1377273'},
#     'reference': {'arxiv_eprint': '1506.02169',
#      'authors': [{'full_name': 'Cranmer, K.'},
#       {'full_name': 'Pavez, J.'},
#       {'full_name': 'Louppe, G.'}],
#      'publication_info': {'year': 2015}}},
#    {'curated_relation': False,
# ...
#      'publication_info': {'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Stoudenmire, E.M.'}],
#      'misc': ['Quantum Science and Technology 3 (3), 034003'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Sun, N.'},
#       {'full_name': 'Yi, J.'},
#       {'full_name': 'Zhang, P.'},
#       {'full_name': 'Shen, H.'},
#       {'full_name': 'Zhai, H.'}],
#      'publication_info': {'artid': '085402',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '98',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Sutton, R.S.'},
#       {'full_name': 'Barto, A.G.'}],
#      'misc': ['Reinforcement learning: An introduction (MIT press)'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1810.07207',
#      'authors': [{'full_name': 'Sweke, R.'},
#       {'full_name': 'Kesselring, M.S.'},
#       {'full_name': 'van Nieuwenburg, E.P.'},
#       {'full_name': 'Eisert, J.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1807.04271',
#      'authors': [{'full_name': 'Tang, E.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Teng, P.'}],
#      'publication_info': {'artid': '033305',
#       'journal_title': 'Phys.Rev.E',
#       'journal_volume': '98',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Thouless, D.J.'},
#       {'full_name': 'Anderson, P.W.'},
#       {'full_name': 'Palmer, R.G.'}],
#      'publication_info': {'artid': '593',
#       'journal_title': 'Phil.Mag.',
#       'journal_volume': '35',
#       'page_start': '593',
#       'year': 1977}}},
#    {'reference': {'arxiv_eprint': 'physics/0004057',
#      'authors': [{'full_name': 'Tishby, N.'},
#       {'full_name': 'Pereira, F.C.'},
#       {'full_name': 'Bialek, W.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2000}}},
#    {'reference': {'authors': [{'full_name': 'Tishby, N.'},
#       {'full_name': 'Zaslavsky, N.'}],
#      'imprint': {'publisher': 'IEEE'},
#      'misc': ['in Information Theory Workshop (ITW) pp. 1-5'],
#      'publication_info': {'year': 2015}}},
#    {'reference': {'authors': [{'full_name': 'Torlai, G.'},
#       {'full_name': 'Mazzola, G.'},
#       {'full_name': 'Carrasquilla, J.'},
#       {'full_name': 'Troyer, M.'},
#       {'full_name': 'Melko, R.'},
#       {'full_name': 'Carleo, G.'}],
#      'publication_info': {'artid': '447',
#       'journal_title': 'Nature Phys.',
#       'journal_volume': '14',
#       'page_start': '447',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Torlai, G.'},
#       {'full_name': 'Melko, R.G.'}],
#      'publication_info': {'artid': '030501',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '119',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Torlai, G.'},
#       {'full_name': 'Melko, R.G.'}],
#      'publication_info': {'artid': '240503',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '120',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Tramel, E.W.'},
#       {'full_name': 'Gabri, M.'},
#       {'full_name': 'Manoel, A.'},
#       {'full_name': 'Caltagirone, F.'},
#       {'full_name': 'Krzakala, F.'}],
#      'publication_info': {'artid': '041006',
#       'journal_title': 'Phys.Rev.X',
#       'journal_volume': '8',
#       'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1699885'},
#     'reference': {'authors': [{'full_name': 'Tsaris, A.'}],
#      'misc': ['(2018), Proceedings, 18th International Workshop on Advanced Computing and Analysis Techniques in Physics Research (ACAT): Seattle, WA, USA, August 21-25'],
#      'publication_info': {'artid': '042023',
#       'journal_title': 'J.Phys.Conf.Ser.',
#       'journal_volume': '1085',
#       'year': 2017}}},
#    {'reference': {'arxiv_eprint': '1803.08718',
#      'authors': [{'full_name': 'Tubiana, J.'},
#       {'full_name': 'Cocco, S.'},
#       {'full_name': 'Monasson, R.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1499552'},
#     'reference': {'authors': [{'full_name': 'Tubiana, J.'},
#       {'full_name': 'Monasson, R.'}],
#      'publication_info': {'artid': '138301',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '118',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Uria, B.'},
#       {'full_name': 'Côt, M.-A.'},
#       {'full_name': 'Gregor, K.'},
#       {'full_name': 'Murray, I.'},
#       {'full_name': 'Larochelle, H.'}],
#      'misc': ['Journal of Machine Learning Research 17 (205), 1'],
#      'publication_info': {'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Valiant, L.G.'}],
#      'misc': ['Communications of the ACM 27 (11), 1134'],
#      'publication_info': {'year': 1984}}},
#    {'reference': {'authors': [{'full_name': 'Van Nieuwenburg, E.P.'},
#       {'full_name': 'Liu, Y.-H.'},
#       {'full_name': 'Huber, S.D.'}],
#      'publication_info': {'artid': '435',
#       'journal_title': 'Nature Phys.',
#       'journal_volume': '13',
#       'page_start': '435',
#       'year': 2017}}},
#    {'reference': {'arxiv_eprint': '1811.12456',
#      'authors': [{'full_name': 'Varsamopoulos, S.'},
#       {'full_name': 'Bertels, K.'},
#       {'full_name': 'Almudever, C.G.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1901.10847',
#      'authors': [{'full_name': 'Varsamopoulos, S.'},
#       {'full_name': 'Bertels, K.'},
#       {'full_name': 'Almudever, C.G.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2019}}},
#    {'reference': {'authors': [{'full_name': 'Varsamopoulos, S.'},
#       {'full_name': 'Criger, B.'},
#       {'full_name': 'Bertels, K.'}],
#      'misc': ['Quantum Science and Technology 3 (1), 015004'],
#      'publication_info': {'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Venderley, J.'},
#       {'full_name': 'Khemani, V.'},
#       {'full_name': 'Kim, E.-A.'}],
#      'publication_info': {'artid': '257204',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '120',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Verstraete, F.'},
#       {'full_name': 'Murg, V.'},
#       {'full_name': 'Cirac, J.I.'}],
#      'publication_info': {'artid': '143',
#       'journal_title': 'Adv.Phys.',
#       'journal_volume': '57',
#       'page_start': '143',
#       'year': 2008}}},
#    {'reference': {'arxiv_eprint': '1902.10104',
#      'authors': [{'full_name': 'Vicentini, F.'},
#       {'full_name': 'Biella, A.'},
#       {'full_name': 'Regnault, N.'},
#       {'full_name': 'Ciuti, C.'}],
#      'misc': ['[cond-mat, physics:quant-ph]'],
#      'publication_info': {'year': 2019}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1236489'},
#     'reference': {'authors': [{'full_name': 'Vidal, G.'}],
#      'publication_info': {'artid': '220405',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '99',
#       'year': 2007}}},
#    {'reference': {'authors': [{'full_name': 'Von Luxburg, U.'}],
#      'publication_info': {'artid': '395',
#       'journal_title': 'Stat.Comput.',
#       'journal_volume': '17',
#       'page_start': '395',
#       'year': 2007}}},
#    {'reference': {'arxiv_eprint': '1805.08349',
#      'authors': [{'full_name': 'Wang, C.'},
#       {'full_name': 'Hu, H.'},
#       {'full_name': 'Lu, Y.M.'}],
#      'misc': ['arXiv preprint arxXiv:'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Wang, C.'},
#       {'full_name': 'Zhai, H.'}],
#      'publication_info': {'artid': '144432',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '96',
#       'year': 2017}}},
#    {'reference': {'authors': [{'full_name': 'Wang, C.'},
#       {'full_name': 'Zhai, H.'}],
#      'publication_info': {'artid': '130507',
#       'journal_title': 'Front.Phys.(Beijing)',
#       'journal_volume': '13',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Wang, L.'}],
#      'publication_info': {'artid': '195105',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '94',
#       'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Wang, L.'}],
#      'publication_info': {'year': 2018},
#      'title': {'title': 'Generative models for physicists'}}},
#    {'reference': {'authors': [{'full_name': 'Watkin, T.'},
#       {'full_name': 'Nadal, J.-P.'}],
#      'misc': ['Journal of Physics A: Mathematical and General 27 (6), 1899'],
#      'publication_info': {'year': 1994}}},
#    {'reference': {'authors': [{'full_name': 'Wecker, D.'},
#       {'full_name': 'Hastings, M.B.'},
#       {'full_name': 'Troyer, M.'}],
#      'publication_info': {'artid': '022309',
#       'journal_title': 'Phys.Rev.A',
#       'journal_volume': '94',
#       'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Wehmeyer, C.'},
#       {'full_name': 'No, F.'}],
#      'publication_info': {'artid': '241703',
#       'journal_title': 'J.Chem.Phys.',
#       'journal_volume': '148',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Wetzel, S.J.'}],
#      'publication_info': {'artid': '022140',
#       'journal_title': 'Phys.Rev.E',
#       'journal_volume': '96',
#       'year': 2017}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/352225'},
#     'reference': {'authors': [{'full_name': 'White, S.R.'}],
#      'publication_info': {'artid': '2863',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '69',
#       'page_start': '2863',
#       'year': 1992}}},
#    {'reference': {'authors': [{'full_name': 'Wigley, P.B.'},
#       {'full_name': 'Everitt, P.J.'}],
#      'misc': ['A. van den Hengel, J. W. Bastian, M. A. Sooriyabandara, G. D. McDonald, K. S. Hardman, C. D. Quinlivan, P. Manju, C. C. N. Kuhn, I. R. Petersen, A. N. Luiten, J. J. Hope, N. P Robins, and M. R. Hush'],
#      'publication_info': {'artid': '25890',
#       'journal_title': 'Sci.Rep.',
#       'journal_volume': '6',
#       'year': 2016}}},
#    {'reference': {'arxiv_eprint': '1809.10606',
#      'authors': [{'full_name': 'Wang, L.'}, {'full_name': 'Zhang, P.'}],
#      'misc': ['Wu, D arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1807.07445',
#      'authors': [{'full_name': 'Xin, T.'},
#       {'full_name': 'Lu, S.'},
#       {'full_name': 'Cao, N.'},
#       {'full_name': 'Anikeeva, G.'},
#       {'full_name': 'Lu, D.'},
#       {'full_name': 'Li, J.'},
#       {'full_name': 'Long, G.'},
#       {'full_name': 'Zeng, B.'}],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1811.06654',
#      'misc': ['Xu, Q., and S. Xu'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Yao, K.'},
#       {'full_name': 'Herr, J.E.'},
#       {'full_name': 'Toth, D.W.'},
#       {'full_name': 'Mckintyre, R.'},
#       {'full_name': 'Parkhill, J.'}],
#      'misc': ['Chem'],
#      'publication_info': {'artid': '2261',
#       'journal_title': 'Science',
#       'journal_volume': '9',
#       'page_start': '2261',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Yedidia, J.S.'},
#       {'full_name': 'Freeman, W.T.'},
#       {'full_name': 'Weiss, Y.'}],
#      'misc': ['Exploring artificial intelligence in the new millennium 8, 236'],
#      'publication_info': {'year': 2003}}},
#    {'reference': {'arxiv_eprint': '1902.07006',
#      'authors': [{'full_name': 'Yoshioka, N.'}, {'full_name': 'Hamazaki, R.'}],
#      'misc': ['[cond-mat, physics:quant-ph]'],
#      'publication_info': {'year': 2019}}},
#    {'reference': {'authors': [{'full_name': 'Zdeborov, L.'},
#       {'full_name': 'Krzakala, F.'}],
#      'publication_info': {'artid': '453',
#       'journal_title': 'Adv.Phys.',
#       'journal_volume': '65',
#       'page_start': '453',
#       'year': 2016}}},
#    {'reference': {'arxiv_eprint': '1611.03530',
#      'authors': [{'full_name': 'Zhang, C.'},
#       {'full_name': 'Bengio, S.'},
#       {'full_name': 'Hardt, M.'},
#       {'full_name': 'Recht, B.'},
#       {'full_name': 'Vinyals, O.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2016}}},
#    {'reference': {'authors': [{'full_name': 'Zhang, L.'},
#       {'full_name': 'Han, J.'},
#       {'full_name': 'Wang, H.'},
#       {'full_name': 'Car, R.'}],
#      'misc': ['and W. E (a)'],
#      'publication_info': {'artid': '143001',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '120',
#       'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1810.11890',
#      'authors': [{'full_name': 'Zhang, L.'},
#       {'full_name': 'Lin, D.-Y.'},
#       {'full_name': 'Wang, H.'},
#       {'full_name': 'Car, R.'}],
#      'misc': ['(b), arXiv preprint'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Zhang, P.'},
#       {'full_name': 'Shen, H.'},
#       {'full_name': 'Zhai, H.'}],
#      'misc': ['(c)'],
#      'publication_info': {'artid': '066401',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '120',
#       'year': 2018}}},
#    {'reference': {'authors': [{'full_name': 'Zhang, W.'},
#       {'full_name': 'Wang, L.'},
#       {'full_name': 'Wang, Z.'}],
#      'publication_info': {'artid': '054208',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '99',
#       'year': 2019}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1720632'},
#     'reference': {'arxiv_eprint': '1902.05965',
#      'authors': [{'full_name': 'Zhang, X.'},
#       {'full_name': 'Wang, Y.'},
#       {'full_name': 'Zhang, W.'},
#       {'full_name': 'Sun, Y.'},
#       {'full_name': 'He, S.'},
#       {'full_name': 'Contardo, G.'},
#       {'full_name': 'Villaescusa-Navarro, F.'},
#       {'full_name': 'Ho, S.'}],
#      'misc': ['arXiv e-prints'],
#      'publication_info': {'year': 2019}}},
#    {'reference': {'arxiv_eprint': '1902.02157',
#      'authors': [{'full_name': 'Zhang, X.-M.'},
#       {'full_name': 'Wei, Z.'},
#       {'full_name': 'Asad, R.'},
#       {'full_name': 'Yang, X.-C.'},
#       {'full_name': 'Wang, X.'}],
#      'misc': ['arXiv preprint'],
#      'publication_info': {'year': 2019}}},
#    {'reference': {'authors': [{'full_name': 'Zhang, Y.'},
#       {'full_name': 'Kim, E.-A.'}],
#      'publication_info': {'artid': '216401',
#       'journal_title': 'Phys.Rev.Lett.',
#       'journal_volume': '118',
#       'year': 2017}}},
#    {'curated_relation': False,
#     'record': {'$ref': 'http://labs.inspirehep.net/api/literature/1598526'},
#     'reference': {'authors': [{'full_name': 'Zhang, Y.'},
#       {'full_name': 'Melko, R.G.'},
#       {'full_name': 'Kim, E.-A.'}],
#      'publication_info': {'artid': '245119',
#       'journal_title': 'Phys.Rev.B',
#       'journal_volume': '96',
#       'year': 2017}}},
#    {'reference': {'arxiv_eprint': '1808.00479',
#      'authors': [{'full_name': 'Zhang, Y.'},
#       {'full_name': 'Mesaros, A.'},
#       {'full_name': 'Fujita, K.'},
#       {'full_name': 'Edkins, S.D.'},
#       {'full_name': 'Hamidian, M.H.'},
#       {'full_name': "Ch'ng, K."},
#       {'full_name': 'Eisaki, H.'},
#       {'full_name': 'Uchida, S.'},
#       {'full_name': 'Davis, J.C.S.'},
#       {'full_name': 'Khatami, E.'},
#       {'full_name': 'Kim, E.-A.'}],
#      'misc': ['(d) [cond-mat, physics:physics]'],
#      'publication_info': {'year': 2018}}},
#    {'reference': {'arxiv_eprint': '1812.08171',
#      'authors': [{'full_name': 'Zheng, Y.'},
#       {'full_name': 'He, H.'},
#       {'full_name': 'Regnault, N.'},
#       {'full_name': 'Bernevig, B.A.'}],
#      'publication_info': {'year': 2018}}}],
#   'self': {'$ref': 'http://labs.inspirehep.net/api/literature/1726790'},
#   'texkeys': ['Carleo:2019ptp'],
#   'titles': [{'source': 'arXiv',
#     'title': 'Machine learning and the physical sciences'}]},
#  'updated': '2019-04-12T08:14:17.994602+00:00'}

# %%
data=r.json()

# %%
data.keys()
# Out:
# dict_keys(['created', 'id', 'links', 'metadata', 'updated'])

# %%
data['created']
# Out:
# '2019-03-27T00:00:00+00:00'

# %%
data['metadata'].keys()
# Out:
# dict_keys(['$schema', '_collections', '_desy_bookkeeping', '_export_to', 'abstracts', 'acquisition_source', 'arxiv_eprints', 'authors', 'citeable', 'control_number', 'core', 'curated', 'document_type', 'documents', 'figures', 'inspire_categories', 'keywords', 'legacy_creation_date', 'legacy_version', 'license', 'number_of_pages', 'preprint_date', 'references', 'self', 'texkeys', 'titles'])

# %%
data['metadata']['citeable']
# Out:
# True

# %%
data['metadata']['refereed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-d8ef5d28982c> in <module>
# ----> 1 data['metadata']['refereed']
#
# KeyError: 'refereed'

# %%
data['metadata']['dois']

# %%
for title in data['metadata']['titles']:
    print(title['title'])

# %%
data['metadata']['_collections']

# %%
data['metadata']['publication_info']

# %%
data['metadata']['arxiv_eprints']

# %%
data['metadata']['arxiv_eprints'][0]['value']

# %%
for author in data['metadata']['authors']:
    print(author['full_name'])

# %%
summarize_record(recid_unpublished)

# %%
print(yaml.dump([summarize_record(recid)]))

# %%
'metadata' in data

# %%
data['metadata']['legacy_creation_date']

# %%
data['metadata']['collaborations']

# %%
myString = "; ".join([a['full_name'] for a in data['metadata']['authors'][:10]])
myString
